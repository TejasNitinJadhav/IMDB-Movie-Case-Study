# %% [markdown]
# # IMDB Movie Rating Case Study
#
#
# ### Project Description
#
# This project is based on the concepts of Data Analytics. We have our IMDB Movie Rating dataset to extract insights from, while the goal of this project is to study the evolution of cinema over decades. Some insights about how the preferable movie genres have changed over time, some graphs of profits that movies make VS their investments, the number of people voting for a particular actor, and the top 250 directors of all time have been studied.
#
# ### Approach :
#
# Starting with data inspection, the entire project is divided into 3 main tasks: inspection, data cleaning and exploratory data analysis. Further, these tasks are divided into more subtasks. Inspection involves getting to know the dataframe, the shape of data and it's data types. Data cleaning involves finding the number of missinf values, their percentages in each column, dropping them if necessary, and building a cleaned new dataframe to finally extract insights from.
#
# ### Tech Stack used :
#
# A Jupyter Notebook was used for the entire analysis purpose, the version being 6.4.0. Besides a notebook , python libraries of pyplot from matplotlib, numpy, and pandas were been used.
#
# ### Insights :
#
# The purpose of analysis this data set was to study the top genres, people's interests over time, and the best actors and directors of all time, and all of these goals have been achieved. For eg: Sci-Fi and Family is the most sought after genre, while Charles Chaplin tops the best directors' list, and Leonardo Caprio has aced all the lists for fan following, with Meryl Streep and Brad Pitt among others.
#
# ### Result :
#
# The IMDB Movie Rating Dataset was successfully analysed and informative insights regarding the top movies and their evolution since the past few years has been studied.

# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
movies = pd.read_csv("IMDB_Movies.csv")
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
movies.shape
# Out:
# (5043, 28)

# %%
movies.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movies.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews          object
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Write your code for column-wise null count here
movies.isna().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          20
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
print("The total null values in the dataframe are : ", movies.isna().sum().sum())
# Out:
# The total null values in the dataframe are :  2697

# %%
# Write your code for row-wise null count here
movies.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       13
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
# Write your code for column-wise null percentages here
columnwise_null = movies.isnull().sum(axis=0)*100/len(movies)
roundedvalues = round(columnwise_null,2)
print(roundedvalues)
# Out:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.40
# language                      0.24
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# aspect_ratio                  6.52
# ...

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# We will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
movies.drop(columns = ["color","director_facebook_likes","actor_1_facebook_likes","actor_2_facebook_likes","actor_3_facebook_likes","actor_2_name","cast_total_facebook_likes","actor_3_name","duration","facenumber_in_poster","content_rating","country","movie_imdb_link","aspect_ratio","plot_keywords"],axis=1,inplace=True)

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
# Write your code for dropping the rows here
movies.dropna(axis=0,subset = ["gross","budget"],inplace=True)
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %% [markdown]
# -  ### Subtask 2.4: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# Write your code for filling the NaN values in the 'language' column here
movies["language"].fillna("English",inplace=True)

# %% [markdown]
# -  ### Subtask 2.5: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left.

# %%
print("Retained rows : ",movies.shape[0])
# Out:
# Retained rows :  3891

# %%
print("Percentage of rows retained : ", round((3891/5043)*100,2))
# Out:
# Percentage of rows retained :  77.16

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
# Write your code for unit conversion here
movies.gross = movies.gross.apply(lambda x : x/1000000)
movies.budget = movies.budget.apply(lambda y : y/1000000)

# %%
movies
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Plot `profit` (y-axis) vs `budget` (x- axis) and observe the outliers using the appropriate chart type.
#     4. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
movies["profit"] = movies.gross - movies.budget
movies
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
movies.sort_values(by = "profit",inplace=True,ascending=False,ignore_index=True)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[15,10])
plt.xlabel("Budget")
plt.ylabel("Profit")
plt.title("Budget VS Profit")
plt.scatter(movies["budget"],movies["profit"])
plt.xlim(0,700)
plt.ylim(-600,600)
plt.show()

# %%
top10 = movies.head(10)
print(top10["movie_title"])
# Out:
# 0                                       Avatar
# 1                               Jurassic World
# 2                                      Titanic
# 3           Star Wars: Episode IV - A New Hope
# 4                   E.T. the Extra-Terrestrial
# 5                                 The Avengers
# 6                                 The Avengers
# 7                                The Lion King
# 8    Star Wars: Episode I - The Phantom Menace
# 9                              The Dark Knight
# Name: movie_title, dtype: object

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After we found out the top 10 profiting movies, we noticed a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`. Note that the same `movie_title` can be there in different languages.

# %%
movies.drop_duplicates(subset="movie_title",keep='first',inplace=True)

# %%
movies.head(10)
# Out:
#         director_name  num_critic_for_reviews       gross  \
# 0       James Cameron                   723.0  760.505847
# 1     Colin Trevorrow                   644.0  652.177271
# 2       James Cameron                   315.0  658.672302
# 3        George Lucas                   282.0  460.935665
# 4    Steven Spielberg                   215.0  434.949459
# 5         Joss Whedon                   703.0  623.279547
# 7        Roger Allers                   186.0  422.783777
# 8        George Lucas                   320.0  474.544677
# 9   Christopher Nolan                   645.0  533.316061
# 10          Gary Ross                   673.0  407.999255
#
#                                       genres         actor_1_name  \
# 0            Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 1           Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 2                              Drama|Romance    Leonardo DiCaprio
# ...

# %%
plt.figure(figsize=[15,10])
plt.xlabel("Budget")
plt.ylabel("Profit")
plt.title("Movie Budget VS Movie Profit")
plt.scatter(movies["budget"],movies["profit"])
plt.xlim(0,700)
plt.ylim(-600,600)
plt.show()

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. New dataframe `IMDb_Top_250` to store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). For all of these movies, the `num_voted_users` is greater than 25,000.
# `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
movies_temp = movies.sort_values(by = "imdb_score",ascending=False)
movies_temp = movies_temp[movies_temp.num_voted_users>25000]
rank = list()
for i in range(1,251):
    rank.append(i)

IMDB_TOP_250 = movies_temp.head(250)
IMDB_TOP_250.insert(0,'Rank',rank)
IMDB_TOP_250
# Out:
#       Rank         director_name  num_critic_for_reviews       gross  \
# 1762     1        Frank Darabont                   199.0   28.341469
# 140      2  Francis Ford Coppola                   208.0  134.821952
# 9        3     Christopher Nolan                   645.0  533.316061
# 612      4  Francis Ford Coppola                   149.0   57.300000
# 227      5     Quentin Tarantino                   215.0  107.930000
# ...    ...                   ...                     ...         ...
# 149    246         Peter Jackson                   645.0  303.001229
# 2316   247  Christophe Barratier                   112.0    3.629758
# 373    248      David O. Russell                   410.0   93.571803
# 1109   249      Darren Aronofsky                   391.0   26.236603
# 175    250               Ang Lee                   287.0  128.067808
#
#                            genres           actor_1_name  \
# 1762                  Crime|Drama         Morgan Freeman
# ...

# %%
Top_Foreign_Lang_Film = IMDB_TOP_250.loc[IMDB_TOP_250["language"]!="English"]
Top_Foreign_Lang_Film
# Out:
#       Rank                     director_name  num_critic_for_reviews  \
# 1688     8                      Sergio Leone                   181.0
# 2304    15                    Akira Kurosawa                   153.0
# 1720    18                Fernando Meirelles                   214.0
# 2823    26                    Hayao Miyazaki                   246.0
# 1494    43  Florian Henckel von Donnersmarck                   215.0
# 1960    46                      Majid Majidi                    46.0
# 2388    47                 Wolfgang Petersen                    96.0
# 2190    49                    Chan-wook Park                   305.0
# 1616    53                    Asghar Farhadi                   354.0
# 3887    58                    Hayao Miyazaki                   174.0
# 2987    59                    S.S. Rajamouli                    44.0
# 3688    60                Jean-Pierre Jeunet                   242.0
# 2434    65                 Thomas Vinterberg                   349.0
# ...

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Grouping the dataframe using the `director_name` column.
#     2. Finding out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.  Incase of a tie in IMDb score between two directors, sort them alphabetically.

# %%
groupdf = movies.groupby("director_name")
mean_df = groupdf.mean()
mean_df = mean_df.reset_index()

# %%
mean_df.sort_values(by = "imdb_score",ascending=False,ignore_index=True,inplace=True)

# %%
top10 = mean_df.head(10)
top10directors = top10["director_name"]
top10directors
# Out:
# 0      Charles Chaplin
# 1            Tony Kaye
# 2         Majid Majidi
# 3      Damien Chazelle
# 4     Alfred Hitchcock
# 5           Ron Fricke
# 6         Sergio Leone
# 7    Christopher Nolan
# 8       Asghar Farhadi
# 9       S.S. Rajamouli
# Name: director_name, dtype: object

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extracting the first two genres from the `genres` column and storing them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
genre = movies["genres"].str.split('|',n=2,expand=True)
movies["genre_1"] = genre[0]
movies["genre_2"] = genre[1]
movies["genre_1"].fillna(value=np.nan,inplace=True)
movies["genre_2"].fillna(value = movies["genre_1"],inplace=True)
movies
# Out:
#          director_name  num_critic_for_reviews       gross  \
# 0        James Cameron                   723.0  760.505847
# 1      Colin Trevorrow                   644.0  652.177271
# 2        James Cameron                   315.0  658.672302
# 3         George Lucas                   282.0  460.935665
# 4     Steven Spielberg                   215.0  434.949459
# ...                ...                     ...         ...
# 3885   Katsuhiro Ôtomo                   150.0    0.439162
# 3886   Katsuhiro Ôtomo                   105.0    0.410388
# 3887    Hayao Miyazaki                   174.0    2.298191
# 3888      Lajos Koltai                    73.0    0.195888
# 3889    Chan-wook Park                   202.0    0.211667
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 1                      Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %%
movies_by_segment = movies.groupby(["genre_1","genre_2"])
movies_by_segment

# %%
PopGenre = movies_by_segment.gross.mean().sort_values(ascending=False)

# %%
PopGenre
# Out:
# genre_1    genre_2
# Family     Sci-Fi       434.949459
# Adventure  Sci-Fi       228.627758
#            Animation    115.949069
#            Family       110.942298
# Action     Adventure    107.880651
#                            ...
# Horror     Musical        0.140244
# Romance    Romance        0.102850
# Thriller   Thriller       0.040513
# Sci-Fi     Sci-Fi         0.018195
# Adventure  War            0.014873
# Name: gross, Length: 103, dtype: float64

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_users_for_review` and identify the actors which have the highest mean.
#     5. Observe the change in number of voted users over decades using a bar chart. Create a column called `decade` which represents the decade to which every movie belongs to. For example, the  `title_year`  year 1923, 1925 should be stored as 1920s. Sort the dataframe based on the column `decade`, group it by `decade` and find the sum of users voted in each decade. Store this in a new data frame called `df_by_decade`.

# %%
Meryl_Streep = movies.loc[movies["actor_1_name"]=='Meryl Streep']
Meryl_Streep
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 259    David Frankel                   208.0  124.732962
# 453   Sydney Pollack                    66.0   87.100000
# 476      Nora Ephron                   252.0   94.125426
# 778    David Frankel                   234.0   63.536011
# 906     Nancy Meyers                   187.0  112.703470
# 1214  Phyllida Lloyd                   331.0   29.959436
# 1224  Stephen Daldry                   174.0   41.597830
# 1454   Robert Altman                   211.0   20.338609
# 1882   Curtis Hanson                    42.0   46.815748
# 2691   Carl Franklin                    64.0   23.209440
# 3309  Robert Redford                   227.0   14.998070
#
#                                genres  actor_1_name  \
# 259              Comedy|Drama|Romance  Meryl Streep
# 453           Biography|Drama|Romance  Meryl Streep
# 476           Biography|Drama|Romance  Meryl Streep
# 778              Comedy|Drama|Romance  Meryl Streep
# ...

# %%
Leo_Caprio = movies.loc[movies["actor_1_name"]=='Leonardo DiCaprio']

# %%
Brad_Pitt = movies.loc[movies["actor_1_name"]=='Brad Pitt']

# %%
frames = [Meryl_Streep,Leo_Caprio,Brad_Pitt]
Combined = pd.concat(frames)

# %%
Combined
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 259           David Frankel                   208.0  124.732962
# 453          Sydney Pollack                    66.0   87.100000
# 476             Nora Ephron                   252.0   94.125426
# 778           David Frankel                   234.0   63.536011
# 906            Nancy Meyers                   187.0  112.703470
# 1214         Phyllida Lloyd                   331.0   29.959436
# 1224         Stephen Daldry                   174.0   41.597830
# 1454          Robert Altman                   211.0   20.338609
# 1882          Curtis Hanson                    42.0   46.815748
# 2691          Carl Franklin                    64.0   23.209440
# 3309         Robert Redford                   227.0   14.998070
# 2             James Cameron                   315.0  658.672302
# 134       Christopher Nolan                   642.0  292.568851
# 179        Steven Spielberg                   194.0  164.435221
# ...

# %%
Combined.groupby('actor_1_name').num_critic_for_reviews.mean()
# Out:
# actor_1_name
# Brad Pitt            245.000000
# Leonardo DiCaprio    322.200000
# Meryl Streep         181.454545
# Name: num_critic_for_reviews, dtype: float64

# %%
Combined.num_user_for_reviews = Combined.num_user_for_reviews.astype('int')
Combined.groupby('actor_1_name').num_user_for_reviews.mean()
# Out:
# actor_1_name
# Brad Pitt            742.352941
# Leonardo DiCaprio    922.550000
# Meryl Streep         297.181818
# Name: num_user_for_reviews, dtype: float64

# %% [markdown]
# **Checkpoint :** `Leonardo` has aced both the lists!

# %%
# calculating decade here
movies["decade"] = movies['title_year'].apply(lambda x:10*(int(x/10)))
movies
# Out:
#          director_name  num_critic_for_reviews       gross  \
# 0        James Cameron                   723.0  760.505847
# 1      Colin Trevorrow                   644.0  652.177271
# 2        James Cameron                   315.0  658.672302
# 3         George Lucas                   282.0  460.935665
# 4     Steven Spielberg                   215.0  434.949459
# ...                ...                     ...         ...
# 3885   Katsuhiro Ôtomo                   150.0    0.439162
# 3886   Katsuhiro Ôtomo                   105.0    0.410388
# 3887    Hayao Miyazaki                   174.0    2.298191
# 3888      Lajos Koltai                    73.0    0.195888
# 3889    Chan-wook Park                   202.0    0.211667
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 1                      Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %%
# creating the data frame df_by_decade here 
df_by_decade = movies.groupby("decade",as_index=False)['num_voted_users'].sum().sort_values(by="decade",ascending=False)
df_by_decade
# Out:
#    decade  num_voted_users
# 9    2010        116240517
# 8    2000        165976645
# 7    1990         69635868
# 6    1980         19344381
# 5    1970          8269834
# 4    1960          2983442
# 3    1950           678336
# 2    1940           230838
# 1    1930           804839
# 0    1920           116392

# %%
# plotting number of voted users vs decade
plt.figure(figsize=[15,10])
plt.plot(df_by_decade["decade"],df_by_decade["num_voted_users"])
plt.xlabel("Decade")
plt.ylabel("Numbers of voters")
plt.show()
